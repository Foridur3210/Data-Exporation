# %%
import pandas as pd
import numpy as np

dt={'a':10,'b':20,'c':0.6658,'d':7.9}
data=pd.Series(dt)
print(data)
# Out:
# a    10.0000
# b    20.0000
# c     0.6658
# d     7.9000
# dtype: float64

# %%
web={"day":[1,2,3,4,5,6],"visitor":[1000,700,6000,1000,400,350],"bounce rate":[20,20,23,15,10,34]}
df=pd.DataFrame(web)
df
# Out:
#    day  visitor  bounce rate
# 0    1     1000           20
# 1    2      700           20
# 2    3     6000           23
# 3    4     1000           15
# 4    5      400           10
# 5    6      350           34

# %%
print(df.head(4))
# Out:
#    day  visitor  bounce rate
# 0    1     1000           20
# 1    2      700           20
# 2    3     6000           23
# 3    4     1000           15

# %%
print(df.tail(3))
# Out:
#    day  visitor  bounce rate
# 3    4     1000           15
# 4    5      400           10
# 5    6      350           34

# %%
x=np.array([[7,8,9],[10,11,12]])
pd.DataFrame(x)
x
# Out:
# array([[ 7,  8,  9],
#        [10, 11, 12]])

# %%
#Checking the data types
print(type(web))
print(type(df))
print(type(x))
# Out:
# <class 'dict'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'numpy.ndarray'>

# %%
df=pd.DataFrame({'col1':['item0','item0','item1','item1'],
                 'col2':['gold','bronze','gold','silver'],
                 'col3':[1,2,np.nan,4]})
df
# Out:
#     col1    col2  col3
# 0  item0    gold   1.0
# 1  item0  bronze   2.0
# 2  item1    gold   NaN
# 3  item1  silver   4.0

# %%
#dimension of dataframe as (rows,columns)
df.shape
# Out:
# (4, 3)

# %%
len(df)
# Out:
# 4

# %%
#an array of columns
df.columns
# Out:
# Index(['col1', 'col2', 'col3'], dtype='object')

# %%
#displays descriptice stats for all columsn
df.describe()
# Out:
#            col3
# count  3.000000
# mean   2.333333
# std    1.527525
# min    1.000000
# 25%    1.500000
# 50%    2.000000
# 75%    3.000000
# max    4.000000

# %%
#sort rows decending by the index
df.sort_index(axis=0,ascending=False)
# Out:
#     col1    col2  col3
# 3  item1  silver   4.0
# 2  item1    gold   NaN
# 1  item0  bronze   2.0
# 0  item0    gold   1.0

# %%
df.sort_index(axis=1,ascending=True)
# Out:
#     col1    col2  col3
# 0  item0    gold   1.0
# 1  item0  bronze   2.0
# 2  item1    gold   NaN
# 3  item1  silver   4.0

# %%
#sort rows decending by the index
df.sort_index(axis=1,ascending=False)
# Out:
#    col3    col2   col1
# 0   1.0    gold  item0
# 1   2.0  bronze  item0
# 2   NaN    gold  item1
# 3   4.0  silver  item1

# %%
#sort by one or multiple columns
df.sort_values(by=['col2','col1'],ascending=False)
# Out:
#     col1    col2  col3
# 3  item1  silver   4.0
# 2  item1    gold   NaN
# 0  item0    gold   1.0
# 1  item0  bronze   2.0

# %%
df.col2
# Out:
# 0      gold
# 1    bronze
# 2      gold
# 3    silver
# Name: col2, dtype: object

# %%
df[['col1','col2']]
# Out:
#     col1    col2
# 0  item0    gold
# 1  item0  bronze
# 2  item1    gold
# 3  item1  silver

# %%
#select any row i.e. 2
df.iloc[2]
# Out:
# col1    item1
# col2     gold
# col3      NaN
# Name: 2, dtype: object

# %%
df.iloc[[1,2]]
# Out:
#     col1    col2  col3
# 1  item0  bronze   2.0
# 2  item1    gold   NaN

# %%
df.iloc[1:3]
# Out:
#     col1    col2  col3
# 1  item0  bronze   2.0
# 2  item1    gold   NaN

# %%
#Specifing column & using iloc function 
df.col1.iloc[1]
# Out:
# 'item0'

# %%
#same as above input
df.iloc[0,0]
# Out:
# 'item0'

# %%
#select first 4 rows and first 2 columns
df.iloc[0:4,0:2]
# Out:
#     col1    col2
# 0  item0    gold
# 1  item0  bronze
# 2  item1    gold
# 3  item1  silver

# %%
df.col3>0
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# Name: col3, dtype: bool

# %%
# query by single column value
df[df.col3>0]
# Out:
#     col1    col2  col3
# 0  item0    gold   1.0
# 1  item0  bronze   2.0
# 3  item1  silver   4.0

# %%
#query by a single columns, if it is in a list of predefined value
df[df['col2'].isin(['gold','silver'])]
# Out:
#     col1    col2  col3
# 0  item0    gold   1.0
# 2  item1    gold   NaN
# 3  item1  silver   4.0

# %%
df.fillna(0)
# Out:
#     col1    col2  col3
# 0  item0    gold   1.0
# 1  item0  bronze   2.0
# 2  item1    gold   0.0
# 3  item1  silver   4.0

# %%
#a conjuction query using two columns
df[(df['col3']>0)&(df['col2']=='silver')]
# Out:
#     col1    col2  col3
# 3  item1  silver   4.0

# %%
#a disjuction query using two columns
df[(df['col3']>0)|(df['col2']=='silver')]
# Out:
#     col1    col2  col3
# 0  item0    gold   1.0
# 1  item0  bronze   2.0
# 3  item1  silver   4.0

# %%
df[df['col2'].isin(['gold'])]
# Out:
#     col1  col2  col3
# 0  item0  gold   1.0
# 2  item1  gold   NaN

# %%
#using contain function
df[df.col2.str.contains('gold')]
# Out:
#     col1  col2  col3
# 0  Item0  gold   1.0
# 2  Item1  gold   NaN

# %%
#modifying dataframe
#modifies the cell identified by its row index and column name
df.at[1,'col1']='bronze and gold'

# %%
#removes all rows with any missing values
df.dropna(how='any')
# Out:
#               col1    col2  col3
# 0            Item0    gold   1.0
# 1  bronze and gold  bronze   2.0
# 3            Item1  silver   4.0

# %%
cereal_df=pd.read_csv("D:\\python\\python\\cereal.csv")
cereal_df2=pd.read_csv("D:\\python\\python\\cereal.csv")

#are they the same?
print(pd.DataFrame.equals(cereal_df,cereal_df2))
# Out:
# True

# %%
#to skip any rows from csv file
df=pd.read_csv("D:\\python\\python\\cereal.csv",skiprows=1)
print(df.head(5))
# Out:
#                    100% Bran  N  C   70  4  1  130    10     5   6  280  25  \
# 0          100% Natural Bran  Q  C  120  3  5   15   2.0   8.0   8  135   0
# 1                   All-Bran  K  C   70  4  1  260   9.0   7.0   5  320  25
# 2  All-Bran with Extra Fiber  K  C   50  4  0  140  14.0   8.0   0  330  25
# 3             Almond Delight  R  C  110  2  2  200   1.0  14.0   8   -1  25
# 4    Apple Cinnamon Cheerios  G  C  110  2  2  180   1.5  10.5  10   70  25
#
#    3  1.1  0.33  68.402973
# 0  3  1.0  1.00  33.983679
# 1  3  1.0  0.33  59.425505
# 2  3  1.0  0.50  93.704912
# 3  3  1.0  0.75  34.384843
# 4  1  1.0  0.75  29.509541

# %%
class_counts=data.groupby('class').size()
print(class_counts)
# Out:
# class
# 0    500
# 1    268
# dtype: int64

# %%
p=data.groupby('class')['plas'].count()
p
# Out:
# class
# 0    500
# 1    268
# Name: plas, dtype: int64

# %%
data.loc[data['class']==0]
# Out:
#      preg  plas  pres  skin  test  mass   pedi  age  class
# 1       1    85    66    29     0  26.6  0.351   31      0
# 3       1    89    66    23    94  28.1  0.167   21      0
# 5       5   116    74     0     0  25.6  0.201   30      0
# 7      10   115     0     0     0  35.3  0.134   29      0
# 10      4   110    92     0     0  37.6  0.191   30      0
# 12     10   139    80     0     0  27.1  1.441   57      0
# 18      1   103    30    38    83  43.3  0.183   33      0
# 20      3   126    88    41   235  39.3  0.704   27      0
# 21      8    99    84     0     0  35.4  0.388   50      0
# 27      1    97    66    15   140  23.2  0.487   22      0
# 28     13   145    82    19   110  22.2  0.245   57      0
# 29      5   117    92     0     0  34.1  0.337   38      0
# 30      5   109    75    26     0  36.0  0.546   60      0
# 32      3    88    58    11    54  24.8  0.267   22      0
# 33      6    92    92     0     0  19.9  0.188   28      0
# ...

# %%
data['plas'].value_counts()
# Out:
# 100    17
# 99     17
# 129    14
# 125    14
# 111    14
# 106    14
# 95     13
# 108    13
# 105    13
# 102    13
# 112    13
# 122    12
# 109    12
# 107    11
# 117    11
# 90     11
# 120    11
# 114    11
# 124    11
# 128    11
# 119    11
# 115    10
# 84     10
# 91      9
# 92      9
# 123     9
# 146     9
# 126     9
# 103     9
# 101     9
#        ..
# 75      2
# 76      2
# 77      2
# 170     2
# 195     2
# 57      2
# 174     2
# 175     2
# 188     2
# 153     2
# 159     2
# 62      1
# 72      1
# 56      1
# 44      1
# 65      1
# 61      1
# 198     1
# 67      1
# 190     1
# 149     1
# 191     1
# 186     1
# 182     1
# 178     1
# 177     1
# 172     1
# 169     1
# 160     1
# 199     1
# Name: plas, Length: 136, dtype: int64

# %%
data.loc[data['class']==1]
# Out:
#      preg  plas  pres  skin  test  mass   pedi  age  class
# 0       6   148    72    35     0  33.6  0.627   50      1
# 2       8   183    64     0     0  23.3  0.672   32      1
# 4       0   137    40    35   168  43.1  2.288   33      1
# 6       3    78    50    32    88  31.0  0.248   26      1
# 8       2   197    70    45   543  30.5  0.158   53      1
# 9       8   125    96     0     0   0.0  0.232   54      1
# 11     10   168    74     0     0  38.0  0.537   34      1
# 13      1   189    60    23   846  30.1  0.398   59      1
# 14      5   166    72    19   175  25.8  0.587   51      1
# 15      7   100     0     0     0  30.0  0.484   32      1
# 16      0   118    84    47   230  45.8  0.551   31      1
# 17      7   107    74     0     0  29.6  0.254   31      1
# 19      1   115    70    30    96  34.6  0.529   32      1
# 22      7   196    90     0     0  39.8  0.451   41      1
# 23      9   119    80    35     0  29.0  0.263   29      1
# ...

# %%
correlations=data.corr(method='pearson')
print(correlations)
# Out:
#            preg      plas      pres      skin      test      mass      pedi  \
# preg   1.000000  0.129459  0.141282 -0.081672 -0.073535  0.017683 -0.033523
# plas   0.129459  1.000000  0.152590  0.057328  0.331357  0.221071  0.137337
# pres   0.141282  0.152590  1.000000  0.207371  0.088933  0.281805  0.041265
# skin  -0.081672  0.057328  0.207371  1.000000  0.436783  0.392573  0.183928
# test  -0.073535  0.331357  0.088933  0.436783  1.000000  0.197859  0.185071
# mass   0.017683  0.221071  0.281805  0.392573  0.197859  1.000000  0.140647
# pedi  -0.033523  0.137337  0.041265  0.183928  0.185071  0.140647  1.000000
# age    0.544341  0.263514  0.239528 -0.113970 -0.042163  0.036242  0.033561
# class  0.221898  0.466581  0.065068  0.074752  0.130548  0.292695  0.173844
#
#             age     class
# preg   0.544341  0.221898
# plas   0.263514  0.466581
# pres   0.239528  0.065068
# skin  -0.113970  0.074752
# test  -0.042163  0.130548
# mass   0.036242  0.292695
# ...

# %%
skew=data.skew()
print(skew)
# Out:
# preg     0.901674
# plas     0.173754
# pres    -1.843608
# skin     0.109372
# test     2.272251
# mass    -0.428982
# pedi     1.919911
# age      1.129597
# class    0.635017
# dtype: float64
